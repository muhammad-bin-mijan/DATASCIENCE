# %%
#for loop
# syntax : for variable in iterable:
             # block of code
# iterable (list,tuple,set,dictionary,str ,generator etc)
# fruits =['banana','apple','cherry']
# for f in fruits:
#     print(f)
#loop iteration using range() and len()
# li = ['banana','cherry','apple']
# for i in range(len(li)):
#     print(li[i])#index wise iteration
#while loop
i = 0
while i<len(li):
    print(li[i])
    i=i+1 #increment
# Out:
# banana
# cherry
# apple

# %%
#list comprehension 
numbers = [1,2,3,4,5]
squares = [num**2 for num in numbers]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
#sort() func will ascend list items alphanumerically
fruits = ['banana','cherry','apple']
# f = fruits.sort() # in place sorting
# print(fruits)
# print(f)
#But if we want to sort descendingly then
fruits.sort(reverse = True)
print(fruits)
number = [12,98,45,67]
# number.sort()
# print(number)
number.sort(reverse =True)
print(number)
# Out:
# ['cherry', 'banana', 'apple']
# [98, 67, 45, 12]

# %%
#list copy
li = ['apple','banana','cherry']
copy_list = li.copy()
print(copy_list )
# Out:
# ['apple', 'banana', 'cherry']
