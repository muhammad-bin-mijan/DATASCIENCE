# %%
#Dictionary is mutable, ordered and duplicate not allowed
student_info = {
    "name":"Shakil",
    "age":19,
    "Division": "Barishal",
    "Education":{
        "School": "MUBC",
        "College": "MCPSC",
        
    }
}
print(student_info)
print(student_info["Education"]["School"])
print(type(student_info))
college_name = student_info.get("Education")
print(college_name)
key = student_info.keys()
print(type(key))
val = student_info.values()
print(val)
# Out:
# {'name': 'Shakil', 'age': 19, 'Division': 'Barishal', 'Education': {'School': 'MUBC', 'College': 'MCPSC'}}
# MUBC
# <class 'dict'>
# {'School': 'MUBC', 'College': 'MCPSC'}
# <class 'dict_keys'>
# dict_values(['Shakil', 19, 'Barishal', {'School': 'MUBC', 'College': 'MCPSC'}])

# %%
contact = {
    "Sadmia" : "01887653",
    "Tiyon" : "0123456",
    "Maruf" : "01322451234",
    "Apurba" : "01234890"
}
contact["Apurba"]="017154321"
print(contact)
contact.update({"Sadmia":"01345678"})
print(contact["Sadmia"])
contact.update({"Rafsan":"01845678"})
print(contact)
Rafsan = contact.pop("Rafsan")
print(Rafsan)
print(contact)
# Out:
# {'Sadmia': '01887653', 'Tiyon': '0123456', 'Maruf': '01322451234', 'Apurba': '017154321'}
# 01345678
# {'Sadmia': '01345678', 'Tiyon': '0123456', 'Maruf': '01322451234', 'Apurba': '017154321', 'Rafsan': '01845678'}
# 01845678
# {'Sadmia': '01345678', 'Tiyon': '0123456', 'Maruf': '01322451234', 'Apurba': '017154321'}
